# %% [markdown]
# Dataset Generation for First Project "ACADEMIC PERFORMANCE INSIGHTS"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import random

# Define parameters
num_of_stdts=42
std_first_names=["Aarav", "Aditi", "Arjun", "Ananya", "Bhavya", "Chaitanya", "Deepak", "Divya", "Ishani", "Karan", "Lakshmi", "Meera", "Nikhil", "Pooja", "Rahul", "Sneha"]
std_last_names=["Sharma", "Reddy", "Iyer", "Gupta", "Nair", "Rallabandi", "Verma", "Joshi", "Malhotra", "Kulkarni"]
Gender=['Male','Female']

# Generating 42 Student records with no duplicates or missing values
uni_data = {
    'Rno': [f"COL{100+i}" for i in range(1,num_of_stdts+1)],
    'Name': [f"{random.choice(std_first_names)} {random.choice(std_last_names)}" for i in range(1,num_of_stdts+1)],
    'Gender': [random.choice(Gender) for i in range(num_of_stdts)],
    'Maths': [random.randint(1,100) for i in range(num_of_stdts)],
    'Physics': [random.randint(1,100) for i in range(num_of_stdts)],
    'Chemistry': [random.randint(1,100) for i in range(num_of_stdts)]
}

# Converting the 42 records into a Data frame
uni_df=pd.DataFrame(uni_data)

# generating 5 student records with duplicate values
dup_df=uni_df.sample(n=5, random_state=42)

# Generating 3 student records with Missing values
null_clmns=['Name','Gender','Maths','Physics','Chemistry']

null_rcds=[]

for i in range(3):
    rcd={
        'Rno': f"COL{143+i}",
        'Name': f"{random.choice(std_first_names)} {random.choice(std_last_names)}",
        'Gender': random.choice(Gender),
        'Maths': random.randint(1,100),
        'Physics': random.randint(1,100),
        'Chemistry': random.randint(1,100)
    }

    random_col=random.choice(null_clmns)

    rcd[random_col]=None

    null_rcds.append(rcd)

# Convert the generated records with missing values into a Data frame
null_df=pd.DataFrame(null_rcds)

# Combining all three Data frames (Unique, Duplicate and Missing Value Records) into a single final Data frame
final_df=pd.concat([uni_df,dup_df,null_df], ignore_index=True)

# Shuffle the records so that they are jumbled and mixed up
final_df = final_df.sample(frac=1).reset_index(drop=True)

# Saving Dataframe as .csv file in the same folder as this notebook
final_df.to_csv('Student_info.csv',index=False)

print("Dataset is created successfully and is saved to 'Student_info.csv' in the current Folder!!")
# Out:
# Dataset is created successfully and is saved to 'Student_info.csv' in the current Folder!!

# %%
# View first 5 student records in the generated dataset
final_df.head()
# Out:
#       Rno                  Name  Gender  Maths  Physics  Chemistry
# 0  COL133    Chaitanya Kulkarni  Female   87.0       53         19
# 1  COL108  Chaitanya Rallabandi    Male   92.0        2         63
# 2  COL145          Sneha Sharma     NaN   43.0       52         15
# 3  COL121           Aarav Reddy    Male   85.0       22         20
# 4  COL111            Arjun Iyer    Male   82.0       58          4

# %% [markdown]
# Step 1 of Project : Data Preparation

# %%
#Load the CSV file into a Pandas DataFrame
import pandas as pd
std_data=pd.read_csv("C:\\Users\\Hp\\Documents\\Python full stack Folder\\PYTHON FULL STACK 1ST PROJECT\\Student_info.csv")
std_df=pd.DataFrame(std_data)

# %%
#Display the first 10 students
std_df.head(10)
# Out:
#       Rno                  Name  Gender  Maths  Physics  Chemistry
# 0  COL133    Chaitanya Kulkarni  Female   87.0       53         19
# 1  COL108  Chaitanya Rallabandi    Male   92.0        2         63
# 2  COL145          Sneha Sharma     NaN   43.0       52         15
# 3  COL121           Aarav Reddy    Male   85.0       22         20
# 4  COL111            Arjun Iyer    Male   82.0       58          4
# 5  COL109        Meera Kulkarni    Male   89.0       41          2
# 6  COL116            Rahul Nair  Female   94.0       80         30
# 7  COL125         Ishani Sharma    Male    6.0       35         27
# 8  COL112       Bhavya Kulkarni    Male   19.0       41          4
# 9  COL143          Ananya Reddy  Female    NaN       31        100

# %%
#Display only female students
female_stds=std_df[std_df['Gender']=='Female']
female_stds
# Out:
#        Rno                Name  Gender  Maths  Physics  Chemistry
# 0   COL133  Chaitanya Kulkarni  Female   87.0       53         19
# 6   COL116          Rahul Nair  Female   94.0       80         30
# 9   COL143        Ananya Reddy  Female    NaN       31        100
# 11  COL123          Arjun Iyer  Female   33.0       66         80
# 18  COL127      Meera Malhotra  Female   38.0       58         81
# 22  COL118      Rahul Kulkarni  Female   32.0       84         35
# 25  COL103         Meera Gupta  Female   62.0       79         77
# 26  COL107        Ishani Joshi  Female   90.0        7         88
# 28  COL136       Lakshmi Reddy  Female   85.0       16         40
# 35  COL141     Bhavya Kulkarni  Female   98.0       73         21
# 38  COL119      Aarav Kulkarni  Female   88.0       12         93
# 39  COL138    Karan Rallabandi  Female  100.0       86         39
# 42  COL124          Karan Nair  Female   82.0       46         53
# 44  COL129        Ishani Joshi  Female   23.0       48         29
# 46  COL140         Bhavya Iyer  Female   42.0       71         71
# 47  COL127      Meera Malhotra  Female   38.0       58         81
# 49  COL128       Bhavya Sharma  Female   35.0       48         83

# %%
#Display Rno and S1 (Maths) marks; remove duplicate records
uni_st_df = std_df.drop_duplicates()
result1=uni_st_df[['Rno','Maths']]
print(result1)
# Out:
#        Rno  Maths
# 0   COL133   87.0
# 1   COL108   92.0
# 2   COL145   43.0
# 3   COL121   85.0
# 4   COL111   82.0
# 5   COL109   89.0
# 6   COL116   94.0
# 7   COL125    6.0
# 8   COL112   19.0
# 9   COL143    NaN
# 10  COL101   25.0
# 11  COL123   33.0
# 12  COL126   93.0
# 13  COL105   20.0
# 14  COL110   41.0
# 16  COL115   55.0
# 17  COL117   18.0
# 18  COL127   38.0
# 19  COL139   54.0
# 20  COL114    2.0
# 21  COL122   12.0
# 22  COL118   32.0
# 25  COL103   62.0
# 26  COL107   90.0
# 27  COL142    3.0
# 28  COL136   85.0
# 29  COL131    2.0
# 30  COL102   92.0
# 31  COL130   42.0
# 32  COL134   12.0
# 33  COL104   55.0
# 34  COL120   77.0
# 35  COL141   98.0
# 36  COL132   38.0
# 37  COL113   69.0
# 38  COL119   88.0
# 39  COL138  100.0
# 40  COL144   67.0
# 42  COL124   82.0
# 43  COL137    4.0
# 44  COL129   23.0
# 45  COL135   98.0
# 46  COL140   42.0
# 48  COL106   53.0
# 49  COL128   35.0

# %%
#Display female students and their S2 (Physics) marks
result2=std_df.loc[std_df['Gender'] == 'Female', ['Rno','Physics']]
print(result2)
# Out:
#        Rno  Physics
# 0   COL133       53
# 6   COL116       80
# 9   COL143       31
# 11  COL123       66
# 18  COL127       58
# 22  COL118       84
# 25  COL103       79
# 26  COL107        7
# 28  COL136       16
# 35  COL141       73
# 38  COL119       12
# 39  COL138       86
# 42  COL124       46
# 44  COL129       48
# 46  COL140       71
# 47  COL127       58
# 49  COL128       48

# %%
#Display male students and their S1 (Maths) marks in ascending order
result3=std_df.loc[std_df['Gender']=='Male', ['Rno','Maths']].sort_values(by='Maths',ascending=True)
print(result3)
# Out:
#        Rno  Maths
# 20  COL114    2.0
# 24  COL114    2.0
# 29  COL131    2.0
# 27  COL142    3.0
# 43  COL137    4.0
# 7   COL125    6.0
# 21  COL122   12.0
# 32  COL134   12.0
# 17  COL117   18.0
# 8   COL112   19.0
# 15  COL105   20.0
# 13  COL105   20.0
# 10  COL101   25.0
# 36  COL132   38.0
# 14  COL110   41.0
# 31  COL130   42.0
# 48  COL106   53.0
# 19  COL139   54.0
# 33  COL104   55.0
# 16  COL115   55.0
# 37  COL113   69.0
# 34  COL120   77.0
# 4   COL111   82.0
# 3   COL121   85.0
# 5   COL109   89.0
# 23  COL109   89.0
# 30  COL102   92.0
# 1   COL108   92.0
# 12  COL126   93.0
# 41  COL126   93.0
# 45  COL135   98.0

# %%
#Display students whose names start with 'S'
result4=std_df[std_df['Name'].str.startswith('S')]
print(result4)
# Out:
#        Rno          Name Gender  Maths  Physics  Chemistry
# 2   COL145  Sneha Sharma    NaN   43.0       52         15
# 16  COL115    Sneha Iyer   Male   55.0       89         35

# %%
#Display students whose names end with 'n'
result5=std_df[std_df['Name'].str.endswith('n')]
print(result5)
# Out:
# Empty DataFrame
# Columns: [Rno, Name, Gender, Maths, Physics, Chemistry]
# Index: []

# %% [markdown]
# Step 2: Data Transformation

# %%
#Add a new column Total Marks = S1 + S2 + S3
std_df['Total Marks']=std_df['Maths']+std_df['Physics']+std_df['Chemistry']
print(std_df)
# Out:
#        Rno                  Name  Gender  Maths  Physics  Chemistry  \
# 0   COL133    Chaitanya Kulkarni  Female   87.0       53         19
# 1   COL108  Chaitanya Rallabandi    Male   92.0        2         63
# 2   COL145          Sneha Sharma     NaN   43.0       52         15
# 3   COL121           Aarav Reddy    Male   85.0       22         20
# 4   COL111            Arjun Iyer    Male   82.0       58          4
# 5   COL109        Meera Kulkarni    Male   89.0       41          2
# 6   COL116            Rahul Nair  Female   94.0       80         30
# 7   COL125         Ishani Sharma    Male    6.0       35         27
# 8   COL112       Bhavya Kulkarni    Male   19.0       41          4
# 9   COL143          Ananya Reddy  Female    NaN       31        100
# 10  COL101      Divya Rallabandi    Male   25.0       46         50
# 11  COL123            Arjun Iyer  Female   33.0       66         80
# 12  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 13  COL105            Meera Nair    Male   20.0       49          8
# 14  COL110       Chaitanya Gupta    Male   41.0       13         92
# 15  COL105            Meera Nair    Male   20.0       49          8
# 16  COL115            Sneha Iyer    Male   55.0       89         35
# 17  COL117          Ananya Joshi    Male   18.0       39         31
# 18  COL127        Meera Malhotra  Female   38.0       58         81
# 19  COL139          Aarav Sharma    Male   54.0       71         73
# 20  COL114          Ananya Joshi    Male    2.0       95         50
# 21  COL122           Ishani Nair    Male   12.0       69         36
# 22  COL118        Rahul Kulkarni  Female   32.0       84         35
# 23  COL109        Meera Kulkarni    Male   89.0       41          2
# 24  COL114          Ananya Joshi    Male    2.0       95         50
# 25  COL103           Meera Gupta  Female   62.0       79         77
# 26  COL107          Ishani Joshi  Female   90.0        7         88
# 27  COL142           Pooja Gupta    Male    3.0       37          3
# 28  COL136         Lakshmi Reddy  Female   85.0       16         40
# 29  COL131      Aarav Rallabandi    Male    2.0       17        100
# 30  COL102      Chaitanya Sharma    Male   92.0       33         92
# 31  COL130          Ananya Verma    Male   42.0       60          9
# 32  COL134            Karan Nair    Male   12.0       42         50
# 33  COL104           Pooja Verma    Male   55.0       72         45
# 34  COL120           Pooja Joshi    Male   77.0       59         63
# 35  COL141       Bhavya Kulkarni  Female   98.0       73         21
# 36  COL132       Chaitanya Reddy    Male   38.0       71         81
# 37  COL113           Pooja Verma    Male   69.0       69         77
# 38  COL119        Aarav Kulkarni  Female   88.0       12         93
# 39  COL138      Karan Rallabandi  Female  100.0       86         39
# 40  COL144        Aarav Kulkarni     NaN   67.0       25         36
# 41  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 42  COL124            Karan Nair  Female   82.0       46         53
# 43  COL137         Lakshmi Gupta    Male    4.0       48         98
# 44  COL129          Ishani Joshi  Female   23.0       48         29
# 45  COL135           Rahul Reddy    Male   98.0       48         77
# 46  COL140           Bhavya Iyer  Female   42.0       71         71
# 47  COL127        Meera Malhotra  Female   38.0       58         81
# 48  COL106           Aarav Gupta    Male   53.0        8         23
# 49  COL128         Bhavya Sharma  Female   35.0       48         83
#
#     Total Marks
# 0         159.0
# 1         157.0
# 2         110.0
# 3         127.0
# 4         144.0
# 5         132.0
# 6         204.0
# 7          68.0
# 8          64.0
# 9           NaN
# 10        121.0
# 11        179.0
# 12        184.0
# 13         77.0
# 14        146.0
# 15         77.0
# 16        179.0
# 17         88.0
# 18        177.0
# 19        198.0
# 20        147.0
# 21        117.0
# 22        151.0
# 23        132.0
# 24        147.0
# 25        218.0
# 26        185.0
# 27         43.0
# 28        141.0
# 29        119.0
# 30        217.0
# 31        111.0
# 32        104.0
# 33        172.0
# 34        199.0
# 35        192.0
# 36        190.0
# 37        215.0
# 38        193.0
# 39        225.0
# 40        128.0
# 41        184.0
# 42        181.0
# 43        150.0
# 44        100.0
# 45        223.0
# 46        184.0
# 47        177.0
# 48         84.0
# 49        166.0

# %%
#Display only female students with their Total Marks
result6=std_df.loc[std_df['Gender']=='Female',['Rno','Total Marks']]
print(result6)
# Out:
#        Rno  Total Marks
# 0   COL133        159.0
# 6   COL116        204.0
# 9   COL143          NaN
# 11  COL123        179.0
# 18  COL127        177.0
# 22  COL118        151.0
# 25  COL103        218.0
# 26  COL107        185.0
# 28  COL136        141.0
# 35  COL141        192.0
# 38  COL119        193.0
# 39  COL138        225.0
# 42  COL124        181.0
# 44  COL129        100.0
# 46  COL140        184.0
# 47  COL127        177.0
# 49  COL128        166.0

# %%
#Calculate percentage for each student and add a Percentage column
std_df['Percentage']=((std_df['Maths']+std_df['Physics']+std_df['Chemistry'])/300.0)*100
std_df['Percentage']=std_df['Percentage'].round(2)
std_df
# Out:
#        Rno                  Name  Gender  Maths  Physics  Chemistry  \
# 0   COL133    Chaitanya Kulkarni  Female   87.0       53         19
# 1   COL108  Chaitanya Rallabandi    Male   92.0        2         63
# 2   COL145          Sneha Sharma     NaN   43.0       52         15
# 3   COL121           Aarav Reddy    Male   85.0       22         20
# 4   COL111            Arjun Iyer    Male   82.0       58          4
# 5   COL109        Meera Kulkarni    Male   89.0       41          2
# 6   COL116            Rahul Nair  Female   94.0       80         30
# 7   COL125         Ishani Sharma    Male    6.0       35         27
# 8   COL112       Bhavya Kulkarni    Male   19.0       41          4
# 9   COL143          Ananya Reddy  Female    NaN       31        100
# 10  COL101      Divya Rallabandi    Male   25.0       46         50
# 11  COL123            Arjun Iyer  Female   33.0       66         80
# 12  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 13  COL105            Meera Nair    Male   20.0       49          8
# 14  COL110       Chaitanya Gupta    Male   41.0       13         92
# 15  COL105            Meera Nair    Male   20.0       49          8
# 16  COL115            Sneha Iyer    Male   55.0       89         35
# 17  COL117          Ananya Joshi    Male   18.0       39         31
# 18  COL127        Meera Malhotra  Female   38.0       58         81
# 19  COL139          Aarav Sharma    Male   54.0       71         73
# 20  COL114          Ananya Joshi    Male    2.0       95         50
# 21  COL122           Ishani Nair    Male   12.0       69         36
# 22  COL118        Rahul Kulkarni  Female   32.0       84         35
# 23  COL109        Meera Kulkarni    Male   89.0       41          2
# 24  COL114          Ananya Joshi    Male    2.0       95         50
# 25  COL103           Meera Gupta  Female   62.0       79         77
# 26  COL107          Ishani Joshi  Female   90.0        7         88
# 27  COL142           Pooja Gupta    Male    3.0       37          3
# 28  COL136         Lakshmi Reddy  Female   85.0       16         40
# 29  COL131      Aarav Rallabandi    Male    2.0       17        100
# 30  COL102      Chaitanya Sharma    Male   92.0       33         92
# 31  COL130          Ananya Verma    Male   42.0       60          9
# 32  COL134            Karan Nair    Male   12.0       42         50
# 33  COL104           Pooja Verma    Male   55.0       72         45
# 34  COL120           Pooja Joshi    Male   77.0       59         63
# 35  COL141       Bhavya Kulkarni  Female   98.0       73         21
# 36  COL132       Chaitanya Reddy    Male   38.0       71         81
# 37  COL113           Pooja Verma    Male   69.0       69         77
# 38  COL119        Aarav Kulkarni  Female   88.0       12         93
# 39  COL138      Karan Rallabandi  Female  100.0       86         39
# 40  COL144        Aarav Kulkarni     NaN   67.0       25         36
# 41  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 42  COL124            Karan Nair  Female   82.0       46         53
# 43  COL137         Lakshmi Gupta    Male    4.0       48         98
# 44  COL129          Ishani Joshi  Female   23.0       48         29
# 45  COL135           Rahul Reddy    Male   98.0       48         77
# 46  COL140           Bhavya Iyer  Female   42.0       71         71
# 47  COL127        Meera Malhotra  Female   38.0       58         81
# 48  COL106           Aarav Gupta    Male   53.0        8         23
# 49  COL128         Bhavya Sharma  Female   35.0       48         83
#
#     Total Marks  Percentage
# 0         159.0       53.00
# 1         157.0       52.33
# 2         110.0       36.67
# 3         127.0       42.33
# 4         144.0       48.00
# 5         132.0       44.00
# 6         204.0       68.00
# 7          68.0       22.67
# 8          64.0       21.33
# 9           NaN         NaN
# 10        121.0       40.33
# 11        179.0       59.67
# 12        184.0       61.33
# 13         77.0       25.67
# 14        146.0       48.67
# 15         77.0       25.67
# 16        179.0       59.67
# 17         88.0       29.33
# 18        177.0       59.00
# 19        198.0       66.00
# 20        147.0       49.00
# 21        117.0       39.00
# 22        151.0       50.33
# 23        132.0       44.00
# 24        147.0       49.00
# 25        218.0       72.67
# 26        185.0       61.67
# 27         43.0       14.33
# 28        141.0       47.00
# 29        119.0       39.67
# 30        217.0       72.33
# 31        111.0       37.00
# 32        104.0       34.67
# 33        172.0       57.33
# 34        199.0       66.33
# 35        192.0       64.00
# 36        190.0       63.33
# 37        215.0       71.67
# 38        193.0       64.33
# 39        225.0       75.00
# 40        128.0       42.67
# 41        184.0       61.33
# 42        181.0       60.33
# 43        150.0       50.00
# 44        100.0       33.33
# 45        223.0       74.33
# 46        184.0       61.33
# 47        177.0       59.00
# 48         84.0       28.00
# 49        166.0       55.33

# %%
'''
Add a new column Grade based on the following conditions:
-> A: 80% – 100%
-> B: 60% – 79%
-> C: 40% – 59%
-> FAIL: Less than 40%
'''
def assign_grade(pt):
    if pd.isna(pt):
        return "Invalid Percentage Value"
    elif pt>=80 and pt<=100:
        return "A"
    elif pt>=60 and pt<=79:
        return "B"
    elif pt>=40 and pt<=59:
        return "C"
    else:
        return "FAIL"
std_df['Grade']=std_df['Percentage'].apply(assign_grade)
std_df
# Out:
#        Rno                  Name  Gender  Maths  Physics  Chemistry  \
# 0   COL133    Chaitanya Kulkarni  Female   87.0       53         19
# 1   COL108  Chaitanya Rallabandi    Male   92.0        2         63
# 2   COL145          Sneha Sharma     NaN   43.0       52         15
# 3   COL121           Aarav Reddy    Male   85.0       22         20
# 4   COL111            Arjun Iyer    Male   82.0       58          4
# 5   COL109        Meera Kulkarni    Male   89.0       41          2
# 6   COL116            Rahul Nair  Female   94.0       80         30
# 7   COL125         Ishani Sharma    Male    6.0       35         27
# 8   COL112       Bhavya Kulkarni    Male   19.0       41          4
# 9   COL143          Ananya Reddy  Female    NaN       31        100
# 10  COL101      Divya Rallabandi    Male   25.0       46         50
# 11  COL123            Arjun Iyer  Female   33.0       66         80
# 12  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 13  COL105            Meera Nair    Male   20.0       49          8
# 14  COL110       Chaitanya Gupta    Male   41.0       13         92
# 15  COL105            Meera Nair    Male   20.0       49          8
# 16  COL115            Sneha Iyer    Male   55.0       89         35
# 17  COL117          Ananya Joshi    Male   18.0       39         31
# 18  COL127        Meera Malhotra  Female   38.0       58         81
# 19  COL139          Aarav Sharma    Male   54.0       71         73
# 20  COL114          Ananya Joshi    Male    2.0       95         50
# 21  COL122           Ishani Nair    Male   12.0       69         36
# 22  COL118        Rahul Kulkarni  Female   32.0       84         35
# 23  COL109        Meera Kulkarni    Male   89.0       41          2
# 24  COL114          Ananya Joshi    Male    2.0       95         50
# 25  COL103           Meera Gupta  Female   62.0       79         77
# 26  COL107          Ishani Joshi  Female   90.0        7         88
# 27  COL142           Pooja Gupta    Male    3.0       37          3
# 28  COL136         Lakshmi Reddy  Female   85.0       16         40
# 29  COL131      Aarav Rallabandi    Male    2.0       17        100
# 30  COL102      Chaitanya Sharma    Male   92.0       33         92
# 31  COL130          Ananya Verma    Male   42.0       60          9
# 32  COL134            Karan Nair    Male   12.0       42         50
# 33  COL104           Pooja Verma    Male   55.0       72         45
# 34  COL120           Pooja Joshi    Male   77.0       59         63
# 35  COL141       Bhavya Kulkarni  Female   98.0       73         21
# 36  COL132       Chaitanya Reddy    Male   38.0       71         81
# 37  COL113           Pooja Verma    Male   69.0       69         77
# 38  COL119        Aarav Kulkarni  Female   88.0       12         93
# 39  COL138      Karan Rallabandi  Female  100.0       86         39
# 40  COL144        Aarav Kulkarni     NaN   67.0       25         36
# 41  COL126  Chaitanya Rallabandi    Male   93.0       58         33
# 42  COL124            Karan Nair  Female   82.0       46         53
# 43  COL137         Lakshmi Gupta    Male    4.0       48         98
# 44  COL129          Ishani Joshi  Female   23.0       48         29
# 45  COL135           Rahul Reddy    Male   98.0       48         77
# 46  COL140           Bhavya Iyer  Female   42.0       71         71
# 47  COL127        Meera Malhotra  Female   38.0       58         81
# 48  COL106           Aarav Gupta    Male   53.0        8         23
# 49  COL128         Bhavya Sharma  Female   35.0       48         83
#
#     Total Marks  Percentage                     Grade
# 0         159.0       53.00                         C
# 1         157.0       52.33                         C
# 2         110.0       36.67                      FAIL
# 3         127.0       42.33                         C
# 4         144.0       48.00                         C
# 5         132.0       44.00                         C
# 6         204.0       68.00                         B
# 7          68.0       22.67                      FAIL
# 8          64.0       21.33                      FAIL
# 9           NaN         NaN  Invalid Percentage Value
# 10        121.0       40.33                         C
# 11        179.0       59.67                      FAIL
# 12        184.0       61.33                         B
# 13         77.0       25.67                      FAIL
# 14        146.0       48.67                         C
# 15         77.0       25.67                      FAIL
# 16        179.0       59.67                      FAIL
# 17         88.0       29.33                      FAIL
# 18        177.0       59.00                         C
# 19        198.0       66.00                         B
# 20        147.0       49.00                         C
# 21        117.0       39.00                      FAIL
# 22        151.0       50.33                         C
# 23        132.0       44.00                         C
# 24        147.0       49.00                         C
# 25        218.0       72.67                         B
# 26        185.0       61.67                         B
# 27         43.0       14.33                      FAIL
# 28        141.0       47.00                         C
# 29        119.0       39.67                      FAIL
# 30        217.0       72.33                         B
# 31        111.0       37.00                      FAIL
# 32        104.0       34.67                      FAIL
# 33        172.0       57.33                         C
# 34        199.0       66.33                         B
# 35        192.0       64.00                         B
# 36        190.0       63.33                         B
# 37        215.0       71.67                         B
# 38        193.0       64.33                         B
# 39        225.0       75.00                         B
# 40        128.0       42.67                         C
# 41        184.0       61.33                         B
# 42        181.0       60.33                         B
# 43        150.0       50.00                         C
# 44        100.0       33.33                      FAIL
# 45        223.0       74.33                         B
# 46        184.0       61.33                         B
# 47        177.0       59.00                         C
# 48         84.0       28.00                      FAIL
# 49        166.0       55.33                         C

# %% [markdown]
# Step 3: Data Visualization

# %%
#Create a Bar Chart showing Percentage of Male vs Female students
from matplotlib import pyplot as plt
import pandas as pd
grouped_by_gen=std_df.groupby('Gender')
groupby_obj=grouped_by_gen['Percentage']
avg_genders=groupby_obj.mean()
plt.bar(avg_genders.index,avg_genders.values,color=['blue','red'])
plt.title("Percentage of Males vs Females")
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.show()

# %%
# Create a Pie Chart showing the PASS vs FAIL percentage of all students
from matplotlib import pyplot as plt
import pandas as pd
pass_stds=std_df[std_df['Grade'].isin(['A','B','C'])]
fail_stds=std_df[std_df['Grade']=="FAIL"]
num_pass_stds=len(pass_stds)
num_fail_stds=len(fail_stds)
plt.title("Percentage of Passed VS Failed Students")
plt.pie([num_pass_stds, num_fail_stds], labels=['PASS', 'FAIL'], autopct="%0.1f%%",explode=[0,0],wedgeprops={'edgecolor':'yellow','linewidth':1},colors=["blue","red"])
plt.show()

# %% [markdown]
# Summary Reports

# %%
#Gender-Based Performance Report (Numeric)
gender_group=std_df.groupby('Gender')
groupby_object=gender_group[['Maths','Physics','Chemistry','Percentage']]
gender_rep=groupby_object.mean()
print("Average Marks obtained based on Gender are\n",gender_rep)
# Out:
# Average Marks obtained based on Gender are
#              Maths    Physics  Chemistry  Percentage
# Gender
# Female  64.187500  53.882353  60.000000   58.999375
# Male    46.516129  49.516129  43.193548   46.408065

# %%
#Visual Report of Gender-based performance
gender_rep.plot(kind='bar', figsize=(10,6))
plt.title('Average Marks based on Gender')
plt.ylabel('Average Score')
plt.xticks(rotation=0)
plt.grid(linestyle='--')
plt.show()

# %%
# Marks-Based Performance Report (Numeric)
marks_summ=std_df[['Maths','Physics','Chemistry']].describe()
print("Marks Statistics are\n",marks_summ)
# Out:
# Marks Statistics are
#              Maths    Physics   Chemistry
# count   49.000000  50.000000   50.000000
# mean    52.632653  50.560000   48.200000
# std     32.980230  23.682561   30.855159
# min      2.000000   2.000000    2.000000
# 25%     23.000000  37.500000   24.000000
# 50%     53.000000  49.000000   42.500000
# 75%     87.000000  69.000000   77.000000
# max    100.000000  95.000000  100.000000

# %%
# Visual Report based on Marks and Grades
grade_cnts=std_df['Grade'].value_counts().sort_index(ascending=True)
plt.pie(grade_cnts,labels=grade_cnts.index,startangle=90,autopct="%1.1f%%",wedgeprops={'linewidth':1,'edgecolor':'yellow'})
plt.title('Visual Report based on Grades')
plt.show()
